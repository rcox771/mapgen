# %%
from mapgen.generators import archipelago
from mapgen.rendering import render
from matplotlib import pyplot as plt
import numpy as np

# %pylab inline


size = 1024
world = archipelago(shape=(size,size))
rendered = render(world)

f, ax = plt.subplots(1, 1, figsize=(10, 8), dpi=100)
ax.imshow(rendered)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['size', 'f', 'axes']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# Elapsed: 4.113

# %%
from mapgen.mapping import World
    
    
W = World()

water_cycle = W.WaterMap.loop()
# Out:
# C:\Users\russ7\code\mapgen\mapgen\mapping.py:153: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert (took < taking, f"took:{took}, taking:{taking}")

# %%
for i in range(1):
    _ = next(water_cycle)

W.show()
# Out:
# 0 adding 100 drops

# %%
a = W.HeightMap.m1 - normalize(W.WaterMap.m1)

f, axes = plt.subplots(1,2, figsize=(8,10))
axes[0].imshow(render(W.HeightMap.m1))

axes[1].imshow(render(a))

# %%
W.WaterMap.show()

# %%
f, axes = plt.subplots(4,4, figsize=(10,10), sharex=True, sharey=True)
axes = axes.flatten()
for i in range(len(axes)):
    ax = axes[i]
    ax.matshow(next(sim))
    ax.set_title(str(i))
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-50-122453ec8334> in <module>()
#       3 for i in range(len(axes)):
#       4     ax = axes[i]
# ----> 5     ax.matshow(next(sim))
#       6     ax.set_title(str(i))
#       7
#
# StopIteration:
